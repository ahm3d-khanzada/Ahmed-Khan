# %% [markdown]
# <a href="https://colab.research.google.com/github/ahm3d-khanzada/Ahmed-Khan/blob/main/Vastra_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vastra - Visual Clothing Try On.
# ---
# Demo for Virtual Try On

# %% [markdown]
# # 1.Setup
#
# - **It will take few minutes to finish installation**

# %%
# clone repository
# !git clone https://github.com/rishabh-s-t/Vastra-Final.git

# install dependencies
# !pip install tensorboardX av torchgeometry flask flask-ngrok iglovikov_helper_functions cloths_segmentation albumentations
# !pip install scipy==1.8.0

# %cd Vastra-Final
# Out:
# fatal: destination path 'Vastra-Final' already exists and is not an empty directory.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 23.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.8.0
#     Uninstalling scipy-1.8.0:
#       Successfully uninstalled scipy-1.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.14.1 which is incompatible.
# ...
#   Using cached scipy-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# ...
# Using cached scipy-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.3 MB)
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.1
#     Uninstalling scipy-1.14.1:
# ...

# %% [markdown]
# # 2. Download Pre-trained Models

# %%
# !rm -r /content/Vastra-Final/Graphonomy-master
# !rm -r /content/Vastra-Final/HR-VITON-main

# %%
# !git clone https://github.com/Gaoyiminggithub/Graphonomy.git
# !git clone https://github.com/sangyun884/HR-VITON.git
# Out:
# Cloning into 'Graphonomy'...
# remote: Enumerating objects: 137, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 137 (delta 2), reused 3 (delta 1), pack-reused 131 (from 1)
# Receiving objects: 100% (137/137), 219.15 KiB | 15.65 MiB/s, done.
# Resolving deltas: 100% (44/44), done.
# Cloning into 'HR-VITON'...
# remote: Enumerating objects: 135, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 135 (delta 67), reused 49 (delta 49), pack-reused 59 (from 1)
# Receiving objects: 100% (135/135), 16.03 MiB | 17.56 MiB/s, done.
# Resolving deltas: 100% (77/77), done.

# %%
# install detectron2
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# !git clone https://github.com/facebookresearch/detectron2.git
# Out:
# ...
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-nuyfrnbh
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-nuyfrnbh
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 5b72c27ae39f99db75d43f18fd1312e1ea934e60
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 12.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 73.9 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade --no-cache-dir gdown

# %cd HR-VITON
# !gdown https://drive.usercontent.google.com/download?id=1T5_YDUhYSSKPC_nZMk2NeC-XXUFoYeNy&export=download
# !gdown https://drive.google.com/u/0/uc?id=1XJTCdRBOPVgVTmqzhVGFAgMm2NLkw5uQ&export=download
# %cd ../

# %cd Graphonomy
# !gdown https://drive.google.com/u/0/uc?id=1eUe18HoH05p0yFUd_sN6GXdTj82aW0m9&export=download
# %cd ../
# Out:
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 5.1.0
#     Uninstalling gdown-5.1.0:
#       Successfully uninstalled gdown-5.1.0
# ...
# /content/Vastra-Final/HR-VITON
# Downloading...
# From: https://drive.usercontent.google.com/download?id=1T5_YDUhYSSKPC_nZMk2NeC-XXUFoYeNy
# To: /content/Vastra-Final/HR-VITON/download?id=1T5_YDUhYSSKPC_nZMk2NeC-XXUFoYeNy
# 100% 2.37k/2.37k [00:00<00:00, 5.50MB/s]
# Downloading...
# From (original): https://drive.google.com/u/0/uc?id=1XJTCdRBOPVgVTmqzhVGFAgMm2NLkw5uQ
# From (redirected): https://drive.google.com/uc?id=1XJTCdRBOPVgVTmqzhVGFAgMm2NLkw5uQ&confirm=t&uuid=01dd6837-0432-4412-9542-2b4d60950ac6
# To: /content/Vastra-Final/HR-VITON/mtviton.pth
# 100% 190M/190M [00:01<00:00, 170MB/s]
# /content/Vastra-Final
# /content/Vastra-Final/Graphonomy
# Downloading...
# From (original): https://drive.google.com/u/0/uc?id=1eUe18HoH05p0yFUd_sN6GXdTj82aW0m9
# ...

# %% [markdown]
# # 3. Upload Cloth Images
# Either use sample images or upload other cloth images

# %%
import os
import shutil
from google.colab import files

# Uncomment the following block if you would like to upload your own cloth images.
# Make sure the input image does not have the name = 'cloth_web.jpg' otherwise the script will crash
input_dir = 'static'
uploaded = files.upload()
for filename in uploaded.keys():
  input_path = os.path.join(input_dir, filename)
  shutil.move(filename, input_path)

try:
  os.remove(input_dir+'/cloth_web.jpg')
  os.rename(input_path, input_dir+'/cloth_web.jpg')
except Exception as e:
  print(str(e))
# Out:
#      <input type="file" id="files-30356b73-77bc-428a-bc6a-7b25c0edfbc3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-30356b73-77bc-428a-bc6a-7b25c0edfbc3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # 4. Upload Person Images
# Either use sample images or upload your images

# %%
# Uncomment the following block if you would like to upload your own images.
# Make sure the input image does not have the name = 'origin_web.jpg' otherwise the script will crash


input_dir = 'static'
uploaded = files.upload()
for filename in uploaded.keys():
  input_path = os.path.join(input_dir, filename)
  shutil.move(filename, input_path)
try:
  os.remove(input_dir+'/origin_web.jpg')
  os.rename(input_path, input_dir+'/origin_web.jpg')
except Exception as e:
  print(str(e))
# Out:
#      <input type="file" id="files-6caec0a5-8848-4955-a106-d1804b4eb004" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6caec0a5-8848-4955-a106-d1804b4eb004">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # 5. Check Images
# check image uploaded successfully

# %%
import matplotlib.pyplot as plt
import cv2

original = cv2.cvtColor(cv2.imread("./static/origin_web.jpg"), cv2.COLOR_BGR2RGB)
cloth = cv2.cvtColor(cv2.imread("./static/cloth_web.jpg"), cv2.COLOR_BGR2RGB)
## Display Images
fig, axes = plt.subplots(nrows=1, ncols=2)
dpi = fig.get_dpi()
fig.set_size_inches(900/ dpi, 448 / dpi)
plt.subplots_adjust(left=0, right=1, bottom=0, top=1)
axes[0].axis('off')
axes[0].imshow(original)
axes[1].axis('off')
axes[1].imshow(cloth)
plt.show()

# %% [markdown]
# # 6. RUN CODE
# * It will take less than 2 minute
# * you can remove background using --background False

# %%
# !python main.py --background False
# Out:
# Get mask of cloth
#
# Get openpose coordinate using posenet
#
# Generate semantic segmentation using Graphonomy-Master library
#
# Constructing DeepLabv3+ model...
# Number of classes: 20
# Output stride: 16
# Number of Input Channels: 3
# load model: ./inference.pth
# time used for the multi-scale image inference is :2.3692592669995065
#
# Generate Densepose image using detectron2 library
#
# [03/19 13:40:01 apply_net]: Loading config from detectron2/projects/DensePose/configs/densepose_rcnn_R_50_FPN_s1x.yaml
# [03/19 13:40:01 apply_net]: Loading model from https://dl.fbaipublicfiles.com/densepose/densepose_rcnn_R_50_FPN_s1x/165712039/model_final_162be9.pkl
# [03/19 13:40:05 apply_net]: Loading data from origin.jpg
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
# ...

# %% [markdown]
# # 7. View Results

# %%
from PIL import Image
from IPython.display import Image

image1 = Image(filename="./static/finalimg.png")
display(image1)
